# %% [markdown]
# # Intro a ML

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
bd = '/content/drive/My Drive/Ironhack/Ironhack archivos/ecomm_users_db.txt'
#link externo https://drive.google.com/file/d/1ZeO2QzvN-qmPiM-S235mmTWBNOsNP92o/view

# %%
X = []

with open(bd,'r') as f:
  for line in f.readlines():
    data = line.split('\t')
    X.append(data)
X= np.array(X)

# %%
X [0:10]
# Out:
# array([['age', 'workclass', 'annual_income', 'education',
#         'usr_credit_lvl', 'marital-status', 'occupation', 'relationship',
#         'race', 'sex', 'capital_gain', 'capital_losses',
#         'hours_per_week', 'native_country', 'income', 'churn',
#         'fraud_score', 'payment_score', 'credit_accepted',
#         'score_money_spent_banks', 'score_user_banks',
#         'user_level_third_parties', 'agility_on_buying',
#         'frequency_on_buying', 'interface_to_show\n'],
#        ['25', ' Private', '148471', ' Some-college', '10', ' Divorced',
#         ' Exec-managerial', ' Unmarried', ' White', ' Female', '0', '0',
#         '25', ' United-States', ' <=50K', '1', '4.86', '4.87', '0',
#         '5.88', '6.2', '0', '1.77', '2.67', '0\n'],
#        ['39', ' Private', '145544', ' Assoc-acdm', '12', ' Separated',
#         ' Craft-repair', ' Not-in-family', ' White', ' Male', '0', '0',
#         '40', ' United-States', ' <=50K', '1', '4.69', '5.37', '0',
#         '5.7', '3.59', '1', '3.72', '4.03', '1\n'],
#        ['45', ' Private', '136612', ' Assoc-voc', '11', ' Divorced',
#         ' Other-service', ' Not-in-family', ' White', ' Female', '0',
#         '0', '8', ' United-States', ' <=50K', '1', '3.82', '5.71', '0',
#         '3.42', '4.47', '2', '6.66', '2.89', '2\n'],
#        ['29', ' Private', '126834', ' HS-grad', '9',
#         ' Married-spouse-absent', ' Tech-support', ' Own-child',
#         ' Black', ' Male', '0', '0', '40', ' United-States', ' <=50K',
#         '1', '2.58', '9.88', '1', '7.55', '7.67', '0', '8.51', '1.98',
#         '3\n'],
#        ['35', ' Private', '122658', ' Bachelors', '13',
#         ' Married-civ-spouse', ' Sales', ' Husband', ' White', ' Male',
#         '0', '0', '52', ' United-States', ' >50K', '0', '8.3', '5.36',
#         '1', '7.16', '2.65', '1', '0.53', '2.98', '0\n'],
#        ['30', ' Private', '118462', ' Some-college', '10',
#         ' Married-civ-spouse', ' Transport-moving', ' Husband', ' Black',
#         ' Male', '0', '0', '35', ' United-States', ' <=50K', '0', '3.41',
#         '1.46', '1', '3.25', '0.55', '2', '4.51', '5.47', '1\n'],
#        ['33', ' Private', '116136', ' Some-college', '10', ' Separated',
#         ' Tech-support', ' Unmarried', ' White', ' Female', '0', '0',
#         '50', ' Columbia', ' <=50K', '1', '4.4', '5.77', '0', '6.63',
#         '5.13', '0', '5.42', '0.26', '2\n'],
#        ['42', ' Local-gov', '112561', ' HS-grad', '9', ' Divorced',
#         ' Other-service', ' Not-in-family', ' Black', ' Male', '0', '0',
#         '40', ' United-States', ' <=50K', '0', '5.35', '5.02', '0',
#         '7.69', '3.85', '1', '9.11', '3.03', '3\n'],
#        ['42', ' Self-emp-inc', '109745', ' Bachelors', '13',
#         ' Married-civ-spouse', ' Sales', ' Husband', ' White', ' Male',
#         '0', '0', '60', ' United-States', ' >50K', '0', '4.77', '5.03',
#         '0', '3.29', '0.29', '2', '1.65', '4.28', '0\n']], dtype='<U24')

# %%
df = pd.DataFrame(X, columns=['age', 'workclass', 'annual_income', 'education', 'usr_credit_lvl',
       'marital-status', 'occupation', 'relationship', 'race', 'sex',
       'capital_gain', 'capital_losses', 'hours_per_week', 'native_country',
       'income', 'churn','fraud_score','payment_score','credit_accepted','score_money_spent_banks','score_user_banks','user_level_third_parties','agility_on_buying',
       'frequency_on_buying','interface_to_show'])
df.head()
# Out:
#    age  workclass  ...  frequency_on_buying    interface_to_show
# 0  age  workclass  ...  frequency_on_buying  interface_to_show\n
# 1   25    Private  ...                 2.67                  0\n
# 2   39    Private  ...                 4.03                  1\n
# 3   45    Private  ...                 2.89                  2\n
# 4   29    Private  ...                 1.98                  3\n
#
# [5 rows x 25 columns]

# %%
df = df.iloc[1:] #con esto borramos la primera linea que repite el nombre de las columnas, sin embargo
#podríamos hacerlo directo, como lo haré en la siguientes líneas.

# %%
df.head()
# Out:
#   age workclass  ... frequency_on_buying interface_to_show
# 1  25   Private  ...                2.67               0\n
# 2  39   Private  ...                4.03               1\n
# 3  45   Private  ...                2.89               2\n
# 4  29   Private  ...                1.98               3\n
# 5  35   Private  ...                2.98               0\n
#
# [5 rows x 25 columns]

# %%
df2 = pd.DataFrame(X[1:], columns = X[0])

# %%
df2.head(2)
# Out:
#   age workclass  ... frequency_on_buying interface_to_show\n
# 0  25   Private  ...                2.67                 0\n
# 1  39   Private  ...                4.03                 1\n
#
# [2 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 1 to 293
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       293 non-null    object
#  1   workclass                 293 non-null    object
#  2   annual_income             293 non-null    object
#  3   education                 293 non-null    object
#  4   usr_credit_lvl            293 non-null    object
#  5   marital-status            293 non-null    object
#  6   occupation                293 non-null    object
#  7   relationship              293 non-null    object
#  8   race                      293 non-null    object
#  9   sex                       293 non-null    object
#  10  capital_gain              293 non-null    object
#  11  capital_losses            293 non-null    object
#  12  hours_per_week            293 non-null    object
#  13  native_country            293 non-null    object
#  14  income                    293 non-null    object
#  15  churn                     293 non-null    object
#  16  fraud_score               293 non-null    object
#  17  payment_score             293 non-null    object
#  18  credit_accepted           293 non-null    object
#  19  score_money_spent_banks   293 non-null    object
#  20  score_user_banks          293 non-null    object
#  21  user_level_third_parties  293 non-null    object
#  22  agility_on_buying         293 non-null    object
#  23  frequency_on_buying       293 non-null    object
#  24  interface_to_show         293 non-null    object
# dtypes: object(25)
# memory usage: 57.4+ KB

# %%
df = df.astype({'annual_income':'int32'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       293 non-null    object
#  1   workclass                 293 non-null    object
#  2   annual_income             293 non-null    int32
#  3   education                 293 non-null    object
#  4   usr_credit_lvl            293 non-null    object
#  5   marital-status            293 non-null    object
#  6   occupation                293 non-null    object
#  7   relationship              293 non-null    object
#  8   race                      293 non-null    object
#  9   sex                       293 non-null    object
#  10  capital_gain              293 non-null    object
#  11  capital_losses            293 non-null    object
#  12  hours_per_week            293 non-null    object
#  13  native_country            293 non-null    object
#  14  income                    293 non-null    object
#  15  churn                     293 non-null    object
#  16  fraud_score               293 non-null    object
#  17  payment_score             293 non-null    object
#  18  credit_accepted           293 non-null    object
#  19  score_money_spent_banks   293 non-null    object
#  20  score_user_banks          293 non-null    object
#  21  user_level_third_parties  293 non-null    object
#  22  agility_on_buying         293 non-null    object
#  23  frequency_on_buying       293 non-null    object
#  24  interface_to_show
#         293 non-null    object
# dtypes: int32(1), object(24)
# memory usage: 56.2+ KB

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
df.boxplot(column=['annual_income'])

# %%
q1,q3 = np.percentile(df['annual_income'],[25,75],axis=0)
iqr = q3-q1
upper = q3+(1.5*iqr)

df_clean = df.loc[df['annual_income']<upper].copy()
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272 entries, 21 to 292
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       272 non-null    object
#  1   workclass                 272 non-null    object
#  2   annual_income             272 non-null    int32
#  3   education                 272 non-null    object
#  4   usr_credit_lvl            272 non-null    object
#  5   marital-status            272 non-null    object
#  6   occupation                272 non-null    object
#  7   relationship              272 non-null    object
#  8   race                      272 non-null    object
#  9   sex                       272 non-null    object
#  10  capital_gain              272 non-null    object
#  11  capital_losses            272 non-null    object
#  12  hours_per_week            272 non-null    object
#  13  native_country            272 non-null    object
#  14  income                    272 non-null    object
#  15  churn                     272 non-null    object
#  16  fraud_score               272 non-null    object
#  17  payment_score             272 non-null    object
#  18  credit_accepted           272 non-null    object
#  19  score_money_spent_banks   272 non-null    object
#  20  score_user_banks          272 non-null    object
#  21  user_level_third_parties  272 non-null    object
#  22  agility_on_buying         272 non-null    object
#  23  frequency_on_buying       272 non-null    object
#  24  interface_to_show
#         272 non-null    object
# dtypes: int32(1), object(24)
# memory usage: 54.2+ KB

# %% [markdown]
# ## Logistic Regression
# Mientras que la regresión lineal se usa para predecir una variable numérica, la regresión logística se usa para la clasificación.
# La logística se utiliza para explicar una relación entre las variables predictoras y una (s) variable (s) de respuesta que pueden tomar valores de 0 o 1.
#
# La regresión logística no necesita satisfacer los mismos supuestos que la regresión lineal. Los únicos supuestos que debemos satisfacer son
# * que las variables predictoras son independientes entre sí y no están correlacionadas entre sí.
# * También necesitamos que la variable de respuesta sea binaria (es decir, que tenga solo dos valores posibles)

# %%
df.head()
# Out:
#   age workclass  ...  frequency_on_buying interface_to_show\n
# 0  25   Private  ...                 2.67                 0\n
# 1  39   Private  ...                 4.03                 1\n
# 2  45   Private  ...                 2.89                 2\n
# 3  29   Private  ...                 1.98                 3\n
# 4  35   Private  ...                 2.98                 0\n
#
# [5 rows x 25 columns]

# %%
import seaborn as sns
sns.countplot(x='churn', data= df_clean)

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.countplot(x='churn',hue='marital-status',data=df_clean)
#hue: variable con la que queremos relacionar los colores de nuestra gráfica.

# %%
df_clean = df_clean[df_clean['workclass']!=' ?'] #aquí indicamos que nos deje todo lo que es diferente de ?

# %%
df_clean
# Out:
#     age workclass  ...  frequency_on_buying interface_to_show
# 125  34   Private  ...                 2.53               0\n
# 134  19   Private  ...                 5.81               1\n
# 257  53   Private  ...                 1.91               2\n
# 212  35   Private  ...                 2.33               0\n
# 145  33   Private  ...                 2.09               0\n
# ..   ..       ...  ...                  ...               ...
# 216  33   Private  ...                 2.52               0\n
# 217  22   Private  ...                 4.25               1\n
# 33   50   Private  ...                  6.1               1\n
# 42   39   Private  ...                 3.91               3\n
# 117  38   Private  ...                 2.23               0\n
#
# [258 rows x 25 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 258 entries, 22 to 292
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       258 non-null    object
#  1   workclass                 258 non-null    object
#  2   annual_income             258 non-null    int32
#  3   education                 258 non-null    object
#  4   usr_credit_lvl            258 non-null    object
#  5   marital-status            258 non-null    object
#  6   occupation                258 non-null    object
#  7   relationship              258 non-null    object
#  8   race                      258 non-null    object
#  9   sex                       258 non-null    object
#  10  capital_gain              258 non-null    object
#  11  capital_losses            258 non-null    object
#  12  hours_per_week            258 non-null    object
#  13  native_country            258 non-null    object
#  14  income                    258 non-null    object
#  15  churn                     258 non-null    object
#  16  fraud_score               258 non-null    object
#  17  payment_score             258 non-null    object
#  18  credit_accepted           258 non-null    object
#  19  score_money_spent_banks   258 non-null    object
#  20  score_user_banks          258 non-null    object
#  21  user_level_third_parties  258 non-null    object
#  22  agility_on_buying         258 non-null    object
#  23  frequency_on_buying       258 non-null    object
#  24  interface_to_show
#         258 non-null    object
# dtypes: int32(1), object(24)
# memory usage: 51.4+ KB

# %%
df_clean.head()
# Out:
#    age workclass  ...  frequency_on_buying interface_to_show\n
# 22  32   Private  ...                 1.29                 2\n
# 23  33   Private  ...                 3.96                 3\n
# 24  34   Private  ...                 3.27                 0\n
# 25  54   Private  ...                  6.3                 1\n
# 26  38   Private  ...                 0.34                 2\n
#
# [5 rows x 25 columns]

# %%
df_clean = df_clean.sample(frac=1)  #con esto simplemente estamos haciendo un mix de todo el data set porque estaban ordenados
#por eso le pedimos que sea una misma frac para que nos deje todo

# %%
df_clean.head()
# Out:
#     age workclass  ...  frequency_on_buying interface_to_show
# 125  34   Private  ...                 2.53               0\n
# 134  19   Private  ...                 5.81               1\n
# 257  53   Private  ...                 1.91               2\n
# 212  35   Private  ...                 2.33               0\n
# 145  33   Private  ...                 2.09               0\n
#
# [5 rows x 25 columns]

# %%
df_clean_dummies = pd.get_dummies(df_clean, columns=['marital-status','sex'])
df_clean_dummies.head()
# Out:
#     age     workclass  ...  sex_ Female sex_ Male
# 97   24       Private  ...            0         1
# 129  53     Local-gov  ...            0         1
# 137  24       Private  ...            0         1
# 241  40   Federal-gov  ...            0         1
# 78   51       Private  ...            0         1
#
# [5 rows x 32 columns]

# %%
df_clean_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 258 entries, 97 to 278
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   age                                    258 non-null    object
#  1   workclass                              258 non-null    object
#  2   annual_income                          258 non-null    int32
#  3   education                              258 non-null    object
#  4   usr_credit_lvl                         258 non-null    object
#  5   occupation                             258 non-null    object
#  6   relationship                           258 non-null    object
#  7   race                                   258 non-null    object
#  8   capital_gain                           258 non-null    object
#  9   capital_losses                         258 non-null    object
#  10  hours_per_week                         258 non-null    object
#  11  native_country                         258 non-null    object
#  12  income                                 258 non-null    object
#  13  churn                                  258 non-null    object
#  14  fraud_score                            258 non-null    object
#  15  payment_score                          258 non-null    object
#  16  credit_accepted                        258 non-null    object
#  17  score_money_spent_banks                258 non-null    object
#  18  score_user_banks                       258 non-null    object
#  19  user_level_third_parties               258 non-null    object
#  20  agility_on_buying                      258 non-null    object
#  21  frequency_on_buying                    258 non-null    object
#  22  interface_to_show
#                      258 non-null    object
#  23  marital-status_ Divorced               258 non-null    uint8
#  24  marital-status_ Married-AF-spouse      258 non-null    uint8
#  25  marital-status_ Married-civ-spouse     258 non-null    uint8
#  26  marital-status_ Married-spouse-absent  258 non-null    uint8
#  27  marital-status_ Never-married          258 non-null    uint8
#  28  marital-status_ Separated              258 non-null    uint8
#  29  marital-status_ Widowed                258 non-null    uint8
#  30  sex_ Female                            258 non-null    uint8
#  31  sex_ Male                              258 non-null    uint8
# dtypes: int32(1), object(22), uint8(9)
# memory usage: 49.6+ KB

# %%
df_clean_dummies = df_clean_dummies.astype({'churn':'int32'})
df_num= df_clean_dummies._get_numeric_data()

# %%
df_num.head()
# Out:
#      annual_income  churn  ...  sex_ Female  sex_ Male
# 125          60979      1  ...            0          1
# 134          60780      0  ...            1          0
# 257          53986      1  ...            0          1
# 212          55690      0  ...            0          1
# 145          59880      0  ...            1          0
#
# [5 rows x 11 columns]

# %%
from sklearn.linear_model import LogisticRegression

x_columns = [col for col in df_num.columns.values if col!= 'churn'] #obtenemos todas las columnas que no son churn
x_columns
# Out:
# ['annual_income',
#  'marital-status_ Divorced',
#  'marital-status_ Married-AF-spouse',
#  'marital-status_ Married-civ-spouse',
#  'marital-status_ Married-spouse-absent',
#  'marital-status_ Never-married',
#  'marital-status_ Separated',
#  'marital-status_ Widowed',
#  'sex_ Female',
#  'sex_ Male']

# %%
df_X = df_num[x_columns]
df_y = df_num['churn']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, test_size=.25, random_state = 101)

# %%
churn_model = LogisticRegression(solver='liblinear') 
#explicación de solvers: http://stackoverflow.com/questions/38640109/logistic-regression-python-solvers-defintions/52388406#52388406
#https://scikit-learn.org/stable/modules/linear_model.html
churn_model.fit(X_train, y_train) #entrenamos churn model con x_train y y_test
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = churn_model.predict(X_test) #vemos la predicción de nuestra regresión logística 
df_predicted = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
df_predicted
# Out:
#      Actual  Predicted
# 147       1          1
# 45        1          1
# 276       0          1
# 134       0          1
# 146       1          1
# ..      ...        ...
# 86        1          1
# 224       0          1
# 256       1          1
# 192       0          1
# 163       1          1
#
# [65 rows x 2 columns]

# %%
churn_model.score(X_train,y_train) 
#esto es la presición del modelo... un 54% de las veces predijo correctamente.... 
#en este caso el 53% no es casi explicativo, puede ser que cambiaramos las columnas para ver qué onda, que tomáramos otras, pero luego lo veremos.
# Out:
# 0.5181347150259067

# %%
churn_model.coef_ #mientras el coeficiente es más grande le das más peso a esa variable, pero en este caso tenemos que normalizar... para que tengan mismo peso
#desde el ppio las columnas
# Out:
# array([[ 1.75980313e-06,  8.29905084e-12,  5.34861166e-12,
#         -2.85616949e-11,  1.60025145e-11,  5.62916234e-12,
#          3.86986880e-12, -6.47258903e-13, -7.95599308e-12,
#          1.78962474e-11]])

# %%
#la conclusión sería: o tenemos que conseguir más información (cuánto llevn con nosotros, su porcentaje de compra...) porque el score sale 53 y porque predice que todos tienen 1... todos se van a ir

# %% [markdown]
# #Clasificación Supervisada
# - DecisionTreeClassifier (Arbol)
# - RandomForestClassifier (Arbol)
# - ExtraTreesClassifier (Arbol)
# - OneVsOneClassifier (SVM)
# - KNeighborsClassifier (K-Nearest Neighbors (KNN))

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %% [markdown]
# ## Arboles
# **Bagging**
# (Bootstrap aggregation) Permite seleccionar de neustro mismos dataset diferentes subsets para entrenar neustro algoritmo. Ayuda a prevenir el Overfitting y mejora la estabilidad de neustros algoritmos a tener en cuenta diferentes muestras que contienen datos similares con reemplazo

# %% [markdown]
# ![Random FOres.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Bagging.png](data:image/png;base64,...)

# %% [markdown]
# ![Arbol De decision.png](data:image/png;base64,...)

# %% [markdown]
# ## Arbol de decisión
#
# Pros
#
# * Los árboles de decisión son fáciles de interpretar y visualizar.
# * Puede capturar fácilmente patrones no lineales.
# * Requiere menos procesamiento previo de datos por parte del usuario, por ejemplo, no hay necesidad de normalizar columnas.
# * Se puede utilizar para la feature engineering, como la predicción de valores perdidos, adecuado para la selección de variables.
# * El árbol de decisión no tiene supuestos sobre la distribución debido a la naturaleza no paramétrica del algoritmo.
#
# Contras
#
# * Sensible a datos ruidosos. Puede sobreajustarse a datos ruidosos.
# * La pequeña variación (o varianza) en los datos puede resultar en un árbol de decisión diferente. Esto se puede reducir mediante algoritmos de embolsado y refuerzo.
# * Los árboles de decisión están sesgados con el conjunto de datos de desequilibrio, por lo que se recomienda equilibrar el conjunto de datos antes de crear el árbol de decisión.

# %%
df_clean.head()
# Out:
#     age     workclass  ...  frequency_on_buying interface_to_show\n
# 97   24       Private  ...                 5.96                 1\n
# 129  53     Local-gov  ...                 5.69                 1\n
# 137  24       Private  ...                 4.05                 1\n
# 241  40   Federal-gov  ...                 2.74                 3\n
# 78   51       Private  ...                 1.95                 2\n
#
# [5 rows x 25 columns]

# %%
df_credit = df_clean[['fraud_score','payment_score','credit_accepted']]
df_credit.head()
# Out:
#     fraud_score payment_score credit_accepted
# 97         4.52          5.58               0
# 129        2.89          8.32               1
# 137        4.27          3.07               1
# 241        5.09          5.34               0
# 78         5.48          4.92               0

# %%
df_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 258 entries, 97 to 278
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fraud_score      258 non-null    object
#  1   payment_score    258 non-null    object
#  2   credit_accepted  258 non-null    object
# dtypes: object(3)
# memory usage: 8.1+ KB

# %%
df_credit = df_credit.astype({'fraud_score':'float','payment_score':'float','credit_accepted':'int32'})

# %%
#seprarar las clases/etiquetas
class_0 = df_credit[(df_credit['credit_accepted']==0)].to_numpy()
class_1 = df_credit[(df_credit['credit_accepted']==1)].to_numpy()

# %%
fig = plt.figure(facecolor = 'w')
plt.scatter(class_0[:,0],class_0[:,1],s =75, facecolor ='black', edgecolors ='black', marker='x') #no se acepta crédito
plt.scatter(class_1[:,0],class_1[:,1],s =75, facecolor ='white', edgecolors ='black', marker='o') #se acepta crédito

# %%
X = df_credit.drop(columns='credit_accepted').to_numpy()
y= df_credit['credit_accepted']

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y, test_size = .25, random_state = 101)

# %%
classifier = DecisionTreeClassifier( random_state=0, max_depth=4) #max_depth es el no. de cortes
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
def visualize_classifier(classifier, X, y, title=''):
  #obteniendo nuestro min y max para el arange
    min_x, max_x = X[:, 0].min() - 1.0, X[:, 0].max() + 1.0
    min_y, max_y = X[:, 1].min() - 1.0, X[:, 1].max() + 1.0
    
    # paso que tomará nuestro grid
    mesh_step_size = 0.01
    
    # Define the mesh grid of X and Y values
    #manera automática de crear un grid para nuestro rango de datos
    #x_vals convierte nustro arreglo de 2D en uno de 1D,
    x_vals, y_vals = np.meshgrid(np.arange(min_x, max_x, mesh_step_size), np.arange(min_y, max_y, mesh_step_size))
    
    #Ejecutando neustro modelo para los valores
    #Ravel permite convertir el arerglo a 1 D
    output = classifier.predict(np.c_[x_vals.ravel(), y_vals.ravel()])
    
    # Cambiamos el tamoño de nuestro output 
    output = output.reshape(x_vals.shape)
    
    # Create a plot
    plt.figure()
    
    # Specify the title
    plt.title(title)
    
    # Creamos el color de nustra grafica. Practicamente es estar mapeando los limites de donde a donde
    #va a colorear y los colores o escalara de colores la determinamos en cmap
    # Colores secuenciales, divergentes, etc...
    #https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
    plt.pcolormesh(x_vals, y_vals, output, cmap=plt.cm.hot)
    
    # Crea un scatterplot con cada valor de X y y, color del marker
    plt.scatter(X[:, 0], X[:, 1], c=y, s=75, edgecolors='black', linewidth=1, cmap=plt.cm.Paired)
    
    # Especigicamos de donde a donde va nuestro plot
    plt.xlim(x_vals.min(), x_vals.max())
    plt.ylim(y_vals.min(), y_vals.max())
    
    # Especificamos marcador en nuestro eje x y y.
    plt.xticks((np.arange(int(X[:, 0].min() - 1), int(X[:, 0].max() + 1), 1.0)))
    plt.yticks((np.arange(int(X[:, 1].min() - 1), int(X[:, 1].max() + 1), 1.0)))
    
    plt.show()

# %%
visualize_classifier(classifier,X_train, y_train, 'Training Dataset')
#lo negro es la distinción donde están cayendo todos los que no se les debería de aceptar el crédito
#Rojos clase 1 . se les acepta el crédito
#Azul clase 0 . no se les acepta el crédito

# %%
y_test_pred = classifier.predict(X_test)
visualize_classifier(classifier, X_test,y_test, 'Test dataset')

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(classifier, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = ['fraud_score','payment_score'],class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('tree.png')
Image(graph.create_png())

#gini es en qué porcentaje nuestros valores están divididos en el primero por ejemplo son 50% fraudes y 50% no 
#además en este diagrama vemos que hay 4 niveles de máxima profundidad
#true son aquellos que sí se concideran fraude, y va descartando según el score... al final 86 pertenecen a la clase 0 y 10 a la clase 1 y según este diagrama
#recordemos que max_depth es el no. de cortes
#este es un árbol de decisión, no es un random forest ja!.... lo que ya dijo que es sí crédito ya dijo que sí, no los vuelve a considerar.
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
confusion_matrix(y_test,y_test_pred) 
#matriz de confusión dice cuántos hay en 
#verdaderos positivos, cuántos falsos positivos, 
#cuántos son falsos negativos y cuántos son verdaderos negativos
#verdaderos positivos: los que etiquetmos como que sí se les tenía que aceptar el crédito y sí se los diste
#falsos positivos no les debiste de haber aceptado el crédito pero sí se los aceptaste 
#falsos negativos: no los aceptaste pero sí los debiste aceptar
#verdaderos negativos: no le debiste aceptar el crédito y no se los aceptaste
# Out:
# array([[35,  3],
#        [ 2, 25]])

# %%
class_names = ['1', '0']
print("\n" + "#"*40)
print("\nClassifier performance on training dataset\n")
print(classification_report(y_train, classifier.predict(X_train), target_names=class_names))
print("#"*40 + "\n")

print("#"*40)
print("\nClassifier performance on test dataset\n")
print(classification_report(y_test, y_test_pred, target_names=class_names))
print("#"*40 + "\n")

plt.show()
#éste es en clasification report 
#en este caso tenemos un .99 de precisión porque si recordamos en el diagrama de arriba hubo un rojito que se nos coló 
#es una manera de evualuar modelos... 
#f1 score es como una suma de recall y de presición
# Out:
# ########################################
#
# Classifier performance on training dataset
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.98      0.99        90
#            0       0.98      1.00      0.99       103
#
#     accuracy                           0.99       193
#    macro avg       0.99      0.99      0.99       193
# weighted avg       0.99      0.99      0.99       193
#
# ########################################
#
# ########################################
#
# Classifier performance on test dataset
#
#               precision    recall  f1-score   support
#
#            1       0.95      0.92      0.93        38
#            0       0.89      0.93      0.91        27
#
#     accuracy                           0.92        65
#    macro avg       0.92      0.92      0.92        65
# weighted avg       0.92      0.92      0.92        65
#
# ########################################

# %%
y_pred_proba = classifier.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve (y_test, y_pred_proba)
auc = metrics.roc_auc_score(y_test,y_pred_proba)
plt.plot(fpr,tpr)
auc
#esta es otra manera de evaluar modelo
# Out:
# 0.935672514619883

# %% [markdown]
# ##Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

# %%
df_clean.head()
# Out:
#     age     workclass  ...  frequency_on_buying interface_to_show\n
# 97   24       Private  ...                 5.96                 1\n
# 129  53     Local-gov  ...                 5.69                 1\n
# 137  24       Private  ...                 4.05                 1\n
# 241  40   Federal-gov  ...                 2.74                 3\n
# 78   51       Private  ...                 1.95                 2\n
#
# [5 rows x 25 columns]

# %%
df_third_parties = df_clean[['score_money_spent_banks','score_user_banks','user_level_third_parties']]
df_third_parties.head()
# Out:
#     score_money_spent_banks score_user_banks user_level_third_parties
# 116                    5.38             3.33                        1
# 25                     3.88              4.2                        0
# 261                    5.17             0.96                        2
# 87                      6.7             4.09                        1
# 242                    4.83             3.16                        1

# %%
df_third_parties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 258 entries, 116 to 247
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   score_money_spent_banks   258 non-null    object
#  1   score_user_banks          258 non-null    object
#  2   user_level_third_parties  258 non-null    object
# dtypes: object(3)
# memory usage: 8.1+ KB

# %%
df_third_parties = df_third_parties.astype({'score_money_spent_banks':'float','score_user_banks':'float','user_level_third_parties':'int32'})
df_third_parties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 258 entries, 116 to 247
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   score_money_spent_banks   258 non-null    float64
#  1   score_user_banks          258 non-null    float64
#  2   user_level_third_parties  258 non-null    int32
# dtypes: float64(2), int32(1)
# memory usage: 7.1 KB

# %%
class_0 = df_third_parties[(df_third_parties['user_level_third_parties']==0)].to_numpy()
class_1 = df_third_parties[(df_third_parties['user_level_third_parties']==1)].to_numpy()
class_2 = df_third_parties[(df_third_parties['user_level_third_parties']==2)].to_numpy()

# %%
plt.figure()
plt.scatter(class_0[:,0],class_0[:,1],s=75,facecolor='white', edgecolors ='black',marker='s')
plt.scatter(class_1[:,0],class_1[:,1],s=75,facecolor='black', edgecolors ='black',marker='o')
plt.scatter(class_2[:,0],class_2[:,1],s=75,facecolor='blue', edgecolors ='black',marker='^')

# %%
X = df_third_parties.drop(columns='user_level_third_parties').to_numpy()
y = df_third_parties['user_level_third_parties']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.25,random_state=0)

# %%
classifier_random = RandomForestClassifier(n_estimators=100,max_depth=4,random_state = 0) #100 son 100 árboles, y 4 es la profundidad

# %%
classifier_random.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=4, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
y_test_pred = classifier_random.predict(X_test)
visualize_classifier(classifier_random,X_train, y_train, 'Test Dataset')#esta es la función que usamos arriba
# Azul es 0, naranja es 1, rojo es 2

# %%
class_names = ['Class-0','Class-1','Class-2']
print("\n" + "#"*40)
print("\nClassifier performance on training dataset\n")
print(classification_report(y_train, classifier_random.predict(X_train), target_names=class_names)) #cambiamos el classifier_random
print("#"*40 + "\n")

print("#"*40)
print("\nClassifier performance on test dataset\n")
print(classification_report(y_test, y_test_pred, target_names=class_names))
print("#"*40 + "\n")

plt.show()
# Out:
# ########################################
#
# Classifier performance on training dataset
#
#               precision    recall  f1-score   support
#
#      Class-0       0.98      0.93      0.95        68
#      Class-1       0.95      0.87      0.91        62
#      Class-2       0.83      0.95      0.89        63
#
#     accuracy                           0.92       193
#    macro avg       0.92      0.92      0.92       193
# weighted avg       0.92      0.92      0.92       193
#
# ########################################
#
# ########################################
#
# Classifier performance on test dataset
#
#               precision    recall  f1-score   support
#
#      Class-0       0.92      0.55      0.69        20
#      Class-1       0.77      0.92      0.84        25
#      Class-2       0.74      0.85      0.79        20
#
#     accuracy                           0.78        65
#    macro avg       0.81      0.77      0.77        65
# weighted avg       0.80      0.78      0.78        65
#
# ########################################

# %%
confusion_matrix(y_test,y_test_pred)
# Out:
# array([[11,  4,  5],
#        [ 1, 23,  1],
#        [ 0,  3, 17]])

# %%
#son puntos que no están, pero con los que estamos haciendo prueba
test_datapoints = np.array([[5,5],[3,6],[6,4],[7,2],[4,4],[5,2]])
for datapoint in test_datapoints:
  probabilities = classifier_random.predict_proba([datapoint])[0] #esto nos va a decir si es de la clase 0,1 ó 2
  predicted_class = 'Class - ' + str(np.argmax(probabilities))
  print( '\n Datapoint:', datapoint)
  print('Predicted Class:',predicted_class)
# Out:
#  Datapoint: [5 5]
# Predicted Class: Class - 0
#
#  Datapoint: [3 6]
# Predicted Class: Class - 0
#
#  Datapoint: [6 4]
# Predicted Class: Class - 1
#
#  Datapoint: [7 2]
# Predicted Class: Class - 1
#
#  Datapoint: [4 4]
# Predicted Class: Class - 2
#
#  Datapoint: [5 2]
# Predicted Class: Class - 2

# %%
visualize_classifier(classifier_random, test_datapoints,[0]*len(test_datapoints), 'Test Data Point RF')

# %%
classifier_random.feature_importances_ #la segunda feature es más importante que la primera
# Out:
# array([0.45204004, 0.54795996])

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(classifier_random.estimators_[1], out_file=dot_data,  #en este caso saca un promedio
                filled=True, rounded=True,
                special_characters=True,feature_names = ['score_money_spent_banks','score_user_banks'],class_names=['0','1','2']) 
          
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('tree.png')
Image(graph.create_png())

# %% [markdown]
# ##Extra Trees Classifier

# %%
#la diferencia con el random forest es que no repite los registros en los samples que toma, y obtenemos un performance más rápido. 
#los outliers le generan mayor ruido
classifier_extra = ExtraTreesClassifier(n_estimators=100, max_depth=4)
classifier_extra.fit(X_train,y_train)
y_test_pred = classifier_extra.predict(X_test)

# %%
visualize_classifier(classifier_extra,X_train, y_train, 'Test Dataset Extra')

# %%
visualize_classifier(classifier_random,X_train, y_train, 'Test Dataset Random')

# %%
class_names = ['Class-0','Class-1','Class-2']
print("\n" + "#"*40)
print("\nClassifier performance on training dataset\n")
print(classification_report(y_train, classifier_extra.predict(X_train), target_names=class_names))
print("#"*40 + "\n")

print("#"*40)
print("\nClassifier performance on test dataset\n")
print(classification_report(y_test, y_test_pred, target_names=class_names))
print("#"*40 + "\n")

plt.show()
# Out:
# ########################################
#
# Classifier performance on training dataset
#
#               precision    recall  f1-score   support
#
#      Class-0       0.91      0.93      0.92        68
#      Class-1       0.93      0.85      0.89        62
#      Class-2       0.85      0.90      0.88        63
#
#     accuracy                           0.90       193
#    macro avg       0.90      0.90      0.90       193
# weighted avg       0.90      0.90      0.90       193
#
# ########################################
#
# ########################################
#
# Classifier performance on test dataset
#
#               precision    recall  f1-score   support
#
#      Class-0       0.93      0.65      0.76        20
#      Class-1       0.77      0.92      0.84        25
#      Class-2       0.81      0.85      0.83        20
#
#     accuracy                           0.82        65
#    macro avg       0.83      0.81      0.81        65
# weighted avg       0.83      0.82      0.81        65
#
# ########################################

# %%
class_names = ['Class-0','Class-1','Class-2']
print("\n" + "#"*40)
print("\nClassifier performance on training dataset\n")
print(classification_report(y_train, classifier_random.predict(X_train), target_names=class_names))
print("#"*40 + "\n")

print("#"*40)
print("\nClassifier performance on test dataset\n")
print(classification_report(y_test, y_test_pred, target_names=class_names))
print("#"*40 + "\n")

plt.show()
# Out:
# ########################################
#
# Classifier performance on training dataset
#
#               precision    recall  f1-score   support
#
#      Class-0       0.98      0.93      0.95        68
#      Class-1       0.95      0.87      0.91        62
#      Class-2       0.83      0.95      0.89        63
#
#     accuracy                           0.92       193
#    macro avg       0.92      0.92      0.92       193
# weighted avg       0.92      0.92      0.92       193
#
# ########################################
#
# ########################################
#
# Classifier performance on test dataset
#
#               precision    recall  f1-score   support
#
#      Class-0       0.93      0.65      0.76        20
#      Class-1       0.77      0.92      0.84        25
#      Class-2       0.81      0.85      0.83        20
#
#     accuracy                           0.82        65
#    macro avg       0.83      0.81      0.81        65
# weighted avg       0.83      0.82      0.81        65
#
# ########################################

# %%
classifier_random.feature_importances_
# Out:
# array([0.45204004, 0.54795996])

# %%
classifier_extra.feature_importances_
# Out:
# array([0.39773058, 0.60226942])

# %% [markdown]
# ##SVM
#
# Las Máquinas de Vectores de Soporte (Support Vector Machines) permiten encontrar la forma óptima de clasificar entre varias clases. La clasificación óptima se realiza maximizando el margen de separación entre las clases.
#
# Este margen siempre se intenta que sea el maximo para que no se calsifique incorercamtente
#
# Los vectores que definen el borde de esta separación son los vectores de soporte. En el caso de que las clases no sean linealmente separables, podemos usar el truco del kernel para añadir una dimensión nueva donde sí lo sean.
#
# Uso de SVM:
#
# * reconocimiento óptico de caracteres
# * detección de caras para que las cámaras digitales enfoquen correctamente
# * filtros de spam para correo electrónico
# * reconocimiento de imágenes a bordo de satélites (saber qué partes de una imagen tienen nubes, tierra, agua, hielo, etc.)
# * Actualmente, las redes neuronales profundas tienen una mayor capacidad de aprendizaje y generalización que los SVM.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn import preprocessing
from sklearn.svm import LinearSVC
from sklearn.multiclass import OneVsOneClassifier

# %%
df_clean.head()
# Out:
#     age     workclass  ...  frequency_on_buying interface_to_show
# 116  33       Private  ...                 3.32               3\n
# 25   34       Private  ...                 3.27               0\n
# 261  37       Private  ...                 0.99               2\n
# 87   62       Private  ...                 2.02               2\n
# 242  40   Federal-gov  ...                 2.74               3\n
#
# [5 rows x 25 columns]

# %%
df_svm = df_clean[['age','annual_income','education','usr_credit_lvl','marital-status','occupation','relationship','capital_gain','capital_losses','hours_per_week','native_country','income']]

# %%
df_svm.head()
# Out:
#     age  annual_income      education  ... hours_per_week  native_country  income
# 116  33          61819        HS-grad  ...             40   United-States   <=50K
# 25   34          84986        HS-grad  ...             40       Nicaragua   <=50K
# 261  37          53844        HS-grad  ...             40   United-States    >50K
# 87   62          66437      Bachelors  ...             60   United-States    >50K
# 242  40          54479   Some-college  ...             40   United-States   <=50K
#
# [5 rows x 12 columns]

# %%
label_encoder =[] #arreglo vacío porque aquí iremos guardando los encoders
df_svm_np = df_svm.to_numpy() #aquí convertimos nuestro df a numpy para poder usar todas las funciones de np

X_encoded = np.empty(df_svm_np.shape)

#después vamos iterando por cada uno de los renglones que tenemos, checamos si es dígito ... si es dígito
#agregamos nuestro registro y no pasa por el label encoder 
#con esto podemos poner de regreso los números con las etiquetas y entender 
for i, item in enumerate(df_svm_np[0]):
  if str(item).isdigit():
    X_encoded[:,i] = df_svm_np[:,i]
  else:
    label_encoder.append(preprocessing.LabelEncoder())
    X_encoded[:,i] = label_encoder[-1].fit_transform(df_svm_np[:, i])

# %%
X = X_encoded[:,:-1].astype(int)
y = X_encoded[:,-1].astype(int)

# %%
X[0]
# Out:
# array([   33, 61819,    11,     9,     4,     2,     1,     0,     0,
#           40,    12])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =.2)

# %%
classifier = OneVsOneClassifier(LinearSVC()) 
# esto es para encontrar la línea que divida mejor a los datos en los hiperplanos #explicado en min 4:11:00 
#https://ironhack.zoom.us/rec/play/rm3DkTWfgg_XhKJggYRvTmUGPHrq6fMsPkMpodhH0C4SxCekPdCXgSI6hrLgTU2h9JRZmsE3h1azt99e.JZyC9WRgDnrMrtXv?startTime=1627128633000&_x_zm_rtaid=ZdSTbwRHQ9Cs4tSwHcYT8g.1627780373811.e2b8b31e584a6d51b46bdafb52c16a5e&_x_zm_rhtaid=551
#se puede aplicar o no pero es mejor aplicarlo.
classifier.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# OneVsOneClassifier(estimator=LinearSVC(C=1.0, class_weight=None, dual=True,
#                                        fit_intercept=True, intercept_scaling=1,
#                                        loss='squared_hinge', max_iter=1000,
#                                        multi_class='ovr', penalty='l2',
#                                        random_state=None, tol=0.0001,
#                                        verbose=0),
#                    n_jobs=None)

# %% [markdown]
# ## KFold Cross validation
# 1. Considere el grupo como un conjunto de datos de prueba o de reserva
# 2. Tome los grupos restantes como un conjunto de datos de entrenamiento
# 3. Coloque un modelo en el conjunto de entrenamiento y evalúelo en el conjunto de prueba
# 4. Conserve la puntuación de la evaluación y descarte el modelo

# %% [markdown]
# ![KFold.png](data:image/png;base64,...)

# %%
accuracy = cross_val_score(classifier,X,y, scoring='accuracy',cv=10) #10 es lo más usual
print(accuracy.mean())
#con cross_val_score... estamos haciendo 10 diferentes sets de entrenamiento... y entrenamos y testeamos tal como está arriba 
#es para ver qué tan bien se comporta nuestro clasificador con diferentes sets
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.7290769230769231
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
#input inventado
input_data = ['37', '29534',' HS-grad', '10', ' Never-married',' Handlers-cleaners',' Not-in-family','0','0','34',' United-States']
#ojo porque todo tenía espacio antes en las categóricas.

input_data_encoded = [-1] * len(input_data) #aplicamos el enconder a nuestros datos

count = 0

for i, item in enumerate(input_data):
  #verificamos si es digito, si si lo dejamos tal cual
    if item.isdigit():
        input_data_encoded[i] = int(input_data[i])
    else:
      #si no, llamamos al label encoder
        input_data_encoded[i] = int(label_encoder[count].transform([input_data[i]]))
        count += 1 

input_data_encoded = np.array(input_data_encoded)

# %%
predicted_class = classifier.predict([input_data_encoded])
print(label_encoder[-1].inverse_transform(predicted_class))
# Out:
# [' <=50K']

# %%
df_svm.head(1)
# Out:
#     age  annual_income education  ... hours_per_week  native_country  income
# 116  33          61819   HS-grad  ...             40   United-States   <=50K
#
# [1 rows x 12 columns]

# %% [markdown]
# ##KNN (K- Narest Neighbor)
#
#
#
# 1.   Calcular la distancia entre el item a clasificar y el resto de items del DS
# de entrenamient
# 2.   Selecciona los k elemenots con menor distancia
# 3. Raliza una "votación" de aquellos que más se acerquen. Los de una clase que
# dominen decidiran el resultado
#
# Las formas más populares de “medir la cercanía” entre puntos son la distancia Euclidiana (la “de siempre”) o la Cosine Similarity
#
# Como pros tiene sobre todo que es sencillo de aprender e implementar. Tiene como contras que utiliza todo el dataset para entrenar “cada punto” y por eso requiere de uso de mucha memoria y recursos de procesamiento (CPU).
#
# Por estas razones kNN tiende a funcionar mejor en datasets pequeños y sin una cantidad enorme de features
#
# Posibles caso de uso
#
#  * sistemas de recomendación
#  * búsqueda semántica
#  * detección de anomalías.

# %% [markdown]
# ![knn.png](data:image/png;base64,...)

# %%
df_clean.head()
# Out:
#     age     workclass  ...  frequency_on_buying interface_to_show
# 116  33       Private  ...                 3.32               3\n
# 25   34       Private  ...                 3.27               0\n
# 261  37       Private  ...                 0.99               2\n
# 87   62       Private  ...                 2.02               2\n
# 242  40   Federal-gov  ...                 2.74               3\n
#
# [5 rows x 25 columns]

# %%
df_interfaces = df_clean[['agility_on_buying','frequency_on_buying','interface_to_show']]
df_interfaces.head()
# Out:
#     agility_on_buying frequency_on_buying interface_to_show
# 116              7.88                3.32               3\n
# 25               2.33                3.27               0\n
# 261              4.25                0.99               2\n
# 87               4.93                2.02               2\n
# 242              8.54                2.74               3\n

# %%
df_interfaces['interface_to_show'] = df['interface_to_show'].str.replace('\n', '')
df_interfaces.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     agility_on_buying frequency_on_buying interface_to_show
# 116              7.88                3.32                 3
# 25               2.33                3.27                 0
# 261              4.25                0.99                 2
# 87               4.93                2.02                 2
# 242              8.54                2.74                 3

# %%
df_interfaces.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 258 entries, 116 to 247
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   agility_on_buying    258 non-null    object
#  1   frequency_on_buying  258 non-null    object
#  2   interface_to_show    258 non-null    object
# dtypes: object(3)
# memory usage: 8.1+ KB

# %%
df_interfaces = df_interfaces.astype({'agility_on_buying':'float','frequency_on_buying':'float','interface_to_show':'int32'})
df_interfaces.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 258 entries, 116 to 247
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   agility_on_buying    258 non-null    float64
#  1   frequency_on_buying  258 non-null    float64
#  2   interface_to_show    258 non-null    int32
# dtypes: float64(2), int32(1)
# memory usage: 7.1 KB

# %%
X = df_interfaces.drop(columns = 'interface_to_show').to_numpy()
y = df_interfaces['interface_to_show']

# %%
plt.figure()
marker_shapes = 'v^os'
mapper = [marker_shapes[i] for i in y]
for i in range(X.shape[0]):
  plt.scatter(X[i,0],X[i,1],marker= mapper[i], s=75,edgecolors ='black', facecolor='none')

# %%
from sklearn import neighbors, datasets

# %%
num_neighbors = 4 #quiero que uses 4 vecinos para determinar dónde cae un usuario nuevo
classifier_knn = neighbors.KNeighborsClassifier(num_neighbors, weights='distance')

# %%
classifier_knn.fit(X,y) #entreno modelo
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                      weights='distance')

# %%
visualize_classifier(classifier_knn,X,y,'KNN')

# %%
#probamos con los siguientes dos puntos
test_datapoint = [5.1, 3.6]
plt.figure()
marker_shapes = 'v^os'
mapper = [marker_shapes[i] for i in y]
for i in range(X.shape[0]):
  plt.scatter(X[i,0],X[i,1],marker= mapper[i], s=75,edgecolors ='black', facecolor='none')

plt.scatter(test_datapoint[0],test_datapoint[1], marker ='X', linewidth=6, s=200,facecolor='black')

# %%
# Triangulos abajo
test_datapoint = [0, 1]
print("Predicted Output", classifier_knn.predict([test_datapoint]))
# Out:
# Predicted Output [0]

# %%
# Circulos
test_datapoint = [4, 1]
print("Predicted Output", classifier_knn.predict([test_datapoint]))
# Out:
# Predicted Output [2]

# %%
# CUadrados
test_datapoint = [8, 3]
print("Predicted Output", classifier_knn.predict([test_datapoint]))
# Out:
# Predicted Output [3]

# %%
# Traingulos arriba
test_datapoint = [4, 6]
print("Predicted Output", classifier_knn.predict([test_datapoint]))
# Out:
# Predicted Output [1]

# %%
test_datapoint = [5.1, 3.6]
print("Predicted Output", classifier_knn.predict([test_datapoint]))
# Out:
# Predicted Output [2]
